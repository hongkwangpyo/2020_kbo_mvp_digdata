# %%
# !pip install import_ipynb
# !pip install plotly
# !pip install imblearn
# !conda install scikit-learn -c conda-forge
# Out:
# Collecting import_ipynb
#   Downloading import-ipynb-0.1.3.tar.gz (4.0 kB)
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py): started
#   Building wheel for import-ipynb (setup.py): finished with status 'done'
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-py3-none-any.whl size=2979 sha256=8395503476ce8fa088bf2c8ee5e0dd257421f96cd39b3f73e1abf41beaf1d3c5
#   Stored in directory: c:\users\tjoeun\appdata\local\pip\cache\wheels\b1\5e\dc\79780689896a056199b0b9f24471e3ee184fbd816df355d5f0
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3
# WARNING: You are using pip version 20.2; however, version 20.2.2 is available.
# You should consider upgrading via the 'c:\users\tjoeun\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import import_ipynb
import kbo_test_v4_0_0 as testPy
# Out:
# importing Jupyter notebook from kbo_test_v4_0_0.ipynb

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\tjoeun\anaconda3\lib\site-packages (4.9.0)
# Requirement already satisfied: six in c:\users\tjoeun\anaconda3\lib\site-packages (from plotly) (1.14.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\tjoeun\anaconda3\lib\site-packages (from plotly) (1.3.3)

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.offline as py

# %%
# matplotlib 한글 출력..
import matplotlib as mpl
import matplotlib.font_manager as fm
mpl.rcParams['axes.unicode_minus'] = False
path = 'C:/Windows/Fonts/malgun.ttf'  # 내가 원하는 폰트로 따로 설정이 가능
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

# %%
df_trian_2019, df_test_2019 = testPy.df_train_data(2019)

# %%
# 2020년 타자 예측

y = df_trian_2019['mvp']
x = df_trian_2019.drop(['player_name', 'mvp'], axis=1)
x1 = df_test_2019.drop(['player_name', 'mvp'], axis=1)

trr = RandomForestClassifier().fit(x, y)
preds = trr.predict_proba(x1)
list1 = preds[:,1]

df_2020_hit_c = df_test_2019.copy()
df_2020_hit_c['per'] = list1
df_2020_hit_c2 = df_2020_hit_c[['player_name','per']].sort_values('per', ascending=False)[:5]#.plot(kind='bar')
plt.bar(df_2020_hit_c2['player_name'], df_2020_hit_c2['per'], data = df_2020_hit_c2)
df_2020_hit_c2
# Out:
#     player_name   per
# 139          샌즈  0.24
# 333        린드블럼  0.23
# 79          김하성  0.17
# 447         양현종  0.12
# 195         박병호  0.10

# %%
df_sq = df_trian_2019[df_trian_2019.mvp == 1]
df_sq = pd.concat([df_sq, df_sq])

# %%
df_sq = pd.concat([df_sq, df_sq])

# %%
df_sq
# Out:
#      player_team  player_AVG  player_G  player_PA  player_AB  player_RH  \
# 25      0.428571    0.872902  0.954545   0.971831   0.967611   1.000000
# 90      0.571429    0.382667  0.598485   0.312812   0.309833   0.185567
# 293     0.428571    0.000000  0.196970   0.000000   0.000000   0.000000
# 112     0.714286    0.290000  1.000000   0.965517   0.932406   0.883721
# 131     0.375000    0.636000  1.000000   0.970332   0.880626   1.000000
# ..           ...         ...       ...        ...        ...        ...
# 180     0.125000    0.370000  1.000000   1.000000   1.000000   1.000000
# 91      0.222222    0.762000  0.986014   0.925350   0.836879   1.000000
# 294     0.000000    0.000000  0.188811   0.000000   0.000000   0.000000
# 440     0.000000    0.000000  0.209790   0.000000   0.000000   0.000000
# 213     0.111111    0.668000  0.965035   0.927581   0.914931   0.881356
#
#      player_HH  player_2B  player_3B  player_HRH  ...  player_IP  player_HP  \
# 25    1.000000   0.419355   0.000000    1.000000  ...   0.000000   0.000000
# 90    0.272727   0.210526   0.000000    0.133333  ...   0.000000   0.000000
# 293   0.000000   0.000000   0.000000    0.000000  ...   0.918443   0.702564
# 112   0.860759   1.000000   0.000000    1.000000  ...   0.000000   0.000000
# 131   0.831395   0.548387   0.000000    1.000000  ...   0.000000   0.000000
# ..         ...        ...        ...         ...  ...        ...        ...
# 180   1.000000   1.000000   1.000000    0.134615  ...   0.000000   0.000000
# 91    0.957447   1.000000   0.714286    0.886792  ...   0.000000   0.000000
# 294   0.000000   0.000000   0.000000    0.000000  ...   0.811229   0.585271
# 440   0.000000   0.000000   0.000000    0.000000  ...   0.958829   0.916667
# 213   0.926316   0.765957   0.100000    1.000000  ...   0.000000   0.000000
#
#      player_HRP  player_BBP  player_HBPP  player_SOP  player_RP  player_ER  \
# 25     0.000000    0.000000     0.000000    0.000000   0.000000   0.000000
# 90     0.000000    0.000000     0.000000    0.000000   0.000000   0.000000
# 293    0.454545    0.448980     0.400000    1.000000   0.524752   0.516484
# 112    0.000000    0.000000     0.000000    0.000000   0.000000   0.000000
# 131    0.000000    0.000000     0.000000    0.000000   0.000000   0.000000
# ..          ...         ...          ...         ...        ...        ...
# 180    0.000000    0.000000     0.000000    0.000000   0.000000   0.000000
# 91     0.000000    0.000000     0.000000    0.000000   0.000000   0.000000
# 294    0.535714    0.626374     0.391304    0.887500   0.504132   0.482456
# 440    0.680000    0.584416     0.000000    0.835979   0.830189   0.762887
# 213    0.000000    0.000000     0.000000    0.000000   0.000000   0.000000
#
#      player_name  mvp
# 25           이대호    1
# 90           윤석민    1
# 293          윤석민    1
# 112          박병호    1
# 131          박병호    1
# ..           ...  ...
# 180          서건창    1
# 91           테임즈    1
# 294          니퍼트    1
# 440          양현종    1
# 213          김재환    1
#
# [640 rows x 40 columns]

# %%
df_trian_2019 = pd.concat([df_trian_2019, df_sq])

# %%
# 2020년 타자 예측

y = df_trian_2019['mvp']
x = df_trian_2019.drop(['player_name', 'mvp'], axis=1)
x1 = df_test_2019.drop(['player_name', 'mvp'], axis=1)

trr = RandomForestClassifier().fit(x, y)
preds = trr.predict_proba(x1)
list1 = preds[:,1]

df_2020_hit_c = df_test_2019.copy()
df_2020_hit_c['per'] = list1
df_2020_hit_c2 = df_2020_hit_c[['player_name','per']].sort_values('per', ascending=False)[:5]#.plot(kind='bar')
plt.bar(df_2020_hit_c2['player_name'], df_2020_hit_c2['per'], data = df_2020_hit_c2)
df_2020_hit_c2
# Out:
#     player_name   per
# 333        린드블럼  0.35
# 139          샌즈  0.33
# 79          김하성  0.09
# 152       페르난데스  0.08
# 130         로하스  0.07
